# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
BASE_URL = "https://www.vlr.gg/"

def get_match_results():
    url = BASE_URL + 'matches'
    response = requests.get(url)
    soup = BeautifulSoup(response.content, 'html.parser')


    matches = []
    for match in soup.select('.match-item'):
        # check if element exists
        teams = match.select_one('.match-item-vs-team-name')
        time = match.select_one('.match-item-time')
        score = match.select_one('.match-item-score')

        match_information = {
            'teams': match.select_one('.match-item-vs-team-name') if teams else 'N/A',
            'time': match.select_one('.match-item-time') if time else 'N/A',
            'score': match.select_one('.match-item-score') if score else 'N/A'
        }
        matches.append(match_information)
    return matches
get_match_results()
# Out:
# [{'teams': <div class="match-item-vs-team-name">
#   <div class="text-of">
#   <span class="flag mod-cl"></span>
#   											LEVIATÁN										</div>
#   </div>,
#   'time': <div class="match-item-time">
#   													2:00 AM											</div>,
#   'score': 'N/A'},
#  {'teams': <div class="match-item-vs-team-name">
#   <div class="text-of">
#   <span class="flag mod-cn"></span>
#   											EDward Gaming										</div>
#   </div>,
#   'time': <div class="match-item-time">
#   													2:00 AM											</div>,
#   'score': 'N/A'},
#  {'teams': <div class="match-item-vs-team-name">
#   <div class="text-of">
#   <span class="flag mod-cl"></span>
#   											University War GC										</div>
#   </div>,
#   'time': <div class="match-item-time">
#   													5:00 PM											</div>,
#   'score': 'N/A'},
#  {'teams': <div class="match-item-vs-team-name">
#   <div class="text-of">
#   <span class="flag mod-un"></span>
#   											FUSION X										</div>
#   </div>,
# ...

# %%
# Set up the ChromeDriver service
service = ChromeService(executable_path=ChromeDriverManager().install())

# initialize driver
driver = webdriver.Chrome(service=service)
driver.get('https://vlr.gg/')

# identify search bar
search_bar = driver.find_element(By.NAME, "q")

# send search query
search = "aspas"
search_bar.send_keys(search)
search_bar.send_keys(Keys.RETURN)
driver.implicitly_wait(10)

# %%
# Out:
# 4.31.1
